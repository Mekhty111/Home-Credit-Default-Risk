# %%
import pandas as pd 

application_train = pd.read_csv(r'../data/raw/application_train.csv')
bureau_balance = pd.read_csv(r'../data/raw/bureau_balance.csv')
bureau = pd.read_csv(r'../data/raw/bureau.csv')
credit_card_balance = pd.read_csv(r'../data/raw/credit_card_balance.csv')
# HomeCredit = pd.read_csv(r'../data/raw/HomeCredit_columns_description.csv')
installments = pd.read_csv(r'../data/raw/installments_payments.csv')
pos_cash = pd.read_csv(r'../data/raw/POS_CASH_balance.csv')
previous_aplication = pd.read_csv(r'../data/raw/previous_application.csv')
sample_submission = pd.read_csv(r'../data/raw/sample_submission.csv')

# %% [markdown]
# ## Application (Train)

# %%
print(application_train.shape)
display(application_train.dtypes)
display(application_train.isnull().mean()*100)
display(application_train.head(3))
# Out:
# (307511, 122)
# SK_ID_CURR                      int64
# TARGET                          int64
# NAME_CONTRACT_TYPE             object
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
#                                ...
# AMT_REQ_CREDIT_BUREAU_DAY     float64
# AMT_REQ_CREDIT_BUREAU_WEEK    float64
# AMT_REQ_CREDIT_BUREAU_MON     float64
# AMT_REQ_CREDIT_BUREAU_QRT     float64
# AMT_REQ_CREDIT_BUREAU_YEAR    float64
# Length: 122, dtype: object
# SK_ID_CURR                     0.000000
# TARGET                         0.000000
# NAME_CONTRACT_TYPE             0.000000
# CODE_GENDER                    0.000000
# FLAG_OWN_CAR                   0.000000
#                                 ...
# AMT_REQ_CREDIT_BUREAU_DAY     13.501631
# AMT_REQ_CREDIT_BUREAU_WEEK    13.501631
# AMT_REQ_CREDIT_BUREAU_MON     13.501631
# AMT_REQ_CREDIT_BUREAU_QRT     13.501631
# AMT_REQ_CREDIT_BUREAU_YEAR    13.501631
# Length: 122, dtype: float64
# ...

# %% [markdown]
# ## Bureau balance

# %%
print(bureau_balance.shape)
display(bureau_balance.dtypes)
display(bureau_balance.isnull().mean()*100)
display(bureau_balance.head(3))
# Out:
# (27299925, 3)
# SK_ID_BUREAU       int64
# MONTHS_BALANCE     int64
# STATUS            object
# dtype: object
# SK_ID_BUREAU      0.0
# MONTHS_BALANCE    0.0
# STATUS            0.0
# dtype: float64
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C

# %% [markdown]
# ## Bureau

# %%
print(bureau.shape)
display(bureau.dtypes)
display(bureau.isnull().mean()*100)
display(bureau.head(3))
# Out:
# (1716428, 17)
# SK_ID_CURR                  int64
# SK_ID_BUREAU                int64
# CREDIT_ACTIVE              object
# CREDIT_CURRENCY            object
# DAYS_CREDIT                 int64
# CREDIT_DAY_OVERDUE          int64
# DAYS_CREDIT_ENDDATE       float64
# DAYS_ENDDATE_FACT         float64
# AMT_CREDIT_MAX_OVERDUE    float64
# CNT_CREDIT_PROLONG          int64
# AMT_CREDIT_SUM            float64
# AMT_CREDIT_SUM_DEBT       float64
# AMT_CREDIT_SUM_LIMIT      float64
# AMT_CREDIT_SUM_OVERDUE    float64
# CREDIT_TYPE                object
# DAYS_CREDIT_UPDATE          int64
# AMT_ANNUITY               float64
# dtype: object
# SK_ID_CURR                 0.000000
# SK_ID_BUREAU               0.000000
# CREDIT_ACTIVE              0.000000
# CREDIT_CURRENCY            0.000000
# DAYS_CREDIT                0.000000
# CREDIT_DAY_OVERDUE         0.000000
# DAYS_CREDIT_ENDDATE        6.149573
# DAYS_ENDDATE_FACT         36.916958
# AMT_CREDIT_MAX_OVERDUE    65.513264
# ...

# %% [markdown]
# ## Bureau

# %%
print(bureau.shape)
display(bureau.dtypes)
display(bureau.isnull().mean()*100)
display(bureau.head(3))
# Out:
# (1716428, 17)
# SK_ID_CURR                  int64
# SK_ID_BUREAU                int64
# CREDIT_ACTIVE              object
# CREDIT_CURRENCY            object
# DAYS_CREDIT                 int64
# CREDIT_DAY_OVERDUE          int64
# DAYS_CREDIT_ENDDATE       float64
# DAYS_ENDDATE_FACT         float64
# AMT_CREDIT_MAX_OVERDUE    float64
# CNT_CREDIT_PROLONG          int64
# AMT_CREDIT_SUM            float64
# AMT_CREDIT_SUM_DEBT       float64
# AMT_CREDIT_SUM_LIMIT      float64
# AMT_CREDIT_SUM_OVERDUE    float64
# CREDIT_TYPE                object
# DAYS_CREDIT_UPDATE          int64
# AMT_ANNUITY               float64
# dtype: object
# SK_ID_CURR                 0.000000
# SK_ID_BUREAU               0.000000
# CREDIT_ACTIVE              0.000000
# CREDIT_CURRENCY            0.000000
# DAYS_CREDIT                0.000000
# CREDIT_DAY_OVERDUE         0.000000
# DAYS_CREDIT_ENDDATE        6.149573
# DAYS_ENDDATE_FACT         36.916958
# AMT_CREDIT_MAX_OVERDUE    65.513264
# ...

# %% [markdown]
# ## Credit card balance

# %%
print(credit_card_balance.shape)
display(credit_card_balance.dtypes)
display(credit_card_balance.isnull().mean()*100)
display(credit_card_balance.head(3))
# Out:
# (3840312, 23)
# SK_ID_PREV                      int64
# SK_ID_CURR                      int64
# MONTHS_BALANCE                  int64
# AMT_BALANCE                   float64
# AMT_CREDIT_LIMIT_ACTUAL         int64
# AMT_DRAWINGS_ATM_CURRENT      float64
# AMT_DRAWINGS_CURRENT          float64
# AMT_DRAWINGS_OTHER_CURRENT    float64
# AMT_DRAWINGS_POS_CURRENT      float64
# AMT_INST_MIN_REGULARITY       float64
# AMT_PAYMENT_CURRENT           float64
# AMT_PAYMENT_TOTAL_CURRENT     float64
# AMT_RECEIVABLE_PRINCIPAL      float64
# AMT_RECIVABLE                 float64
# AMT_TOTAL_RECEIVABLE          float64
# CNT_DRAWINGS_ATM_CURRENT      float64
# CNT_DRAWINGS_CURRENT            int64
# CNT_DRAWINGS_OTHER_CURRENT    float64
# CNT_DRAWINGS_POS_CURRENT      float64
# CNT_INSTALMENT_MATURE_CUM     float64
# NAME_CONTRACT_STATUS           object
# SK_DPD                          int64
# SK_DPD_DEF                      int64
# dtype: object
# SK_ID_PREV                     0.000000
# ...

# %% [markdown]
# ## Installments payments

# %%
print(installments.shape)
display(installments.dtypes)
display(installments.isnull().mean()*100)
display(installments.head(3))
# Out:
# (13605401, 8)
# SK_ID_PREV                  int64
# SK_ID_CURR                  int64
# NUM_INSTALMENT_VERSION    float64
# NUM_INSTALMENT_NUMBER       int64
# DAYS_INSTALMENT           float64
# DAYS_ENTRY_PAYMENT        float64
# AMT_INSTALMENT            float64
# AMT_PAYMENT               float64
# dtype: object
# SK_ID_PREV                0.000000
# SK_ID_CURR                0.000000
# NUM_INSTALMENT_VERSION    0.000000
# NUM_INSTALMENT_NUMBER     0.000000
# DAYS_INSTALMENT           0.000000
# DAYS_ENTRY_PAYMENT        0.021352
# AMT_INSTALMENT            0.000000
# AMT_PAYMENT               0.021352
# dtype: float64
#    SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0     1054186      161674                     1.0                      6
# 1     1330831      151639                     0.0                     34
# 2     2085231      193053                     2.0                      1
#
# ...

# %% [markdown]
# ## POS-CASH balance

# %%
print(pos_cash.shape)
display(pos_cash.dtypes)
display(pos_cash.isnull().mean()*100)
display(pos_cash.head(3))
# Out:
# (10001358, 8)
# SK_ID_PREV                 int64
# SK_ID_CURR                 int64
# MONTHS_BALANCE             int64
# CNT_INSTALMENT           float64
# CNT_INSTALMENT_FUTURE    float64
# NAME_CONTRACT_STATUS      object
# SK_DPD                     int64
# SK_DPD_DEF                 int64
# dtype: object
# SK_ID_PREV               0.000000
# SK_ID_CURR               0.000000
# MONTHS_BALANCE           0.000000
# CNT_INSTALMENT           0.260675
# CNT_INSTALMENT_FUTURE    0.260835
# NAME_CONTRACT_STATUS     0.000000
# SK_DPD                   0.000000
# SK_DPD_DEF               0.000000
# dtype: float64
#    SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0     1803195      182943             -31            48.0
# 1     1715348      367990             -33            36.0
# 2     1784872      397406             -32            12.0
#
#    CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                   45.0               Active       0           0
# ...

# %% [markdown]
# ## Previous applications

# %%
print(previous_aplication.shape)
display(previous_aplication.dtypes)
display(previous_aplication.isnull().mean()*100)
display(previous_aplication.head(3))
# Out:
# (1670214, 37)
# SK_ID_PREV                       int64
# SK_ID_CURR                       int64
# NAME_CONTRACT_TYPE              object
# AMT_ANNUITY                    float64
# AMT_APPLICATION                float64
# AMT_CREDIT                     float64
# AMT_DOWN_PAYMENT               float64
# AMT_GOODS_PRICE                float64
# WEEKDAY_APPR_PROCESS_START      object
# HOUR_APPR_PROCESS_START          int64
# FLAG_LAST_APPL_PER_CONTRACT     object
# NFLAG_LAST_APPL_IN_DAY           int64
# RATE_DOWN_PAYMENT              float64
# RATE_INTEREST_PRIMARY          float64
# RATE_INTEREST_PRIVILEGED       float64
# NAME_CASH_LOAN_PURPOSE          object
# NAME_CONTRACT_STATUS            object
# DAYS_DECISION                    int64
# NAME_PAYMENT_TYPE               object
# CODE_REJECT_REASON              object
# NAME_TYPE_SUITE                 object
# NAME_CLIENT_TYPE                object
# NAME_GOODS_CATEGORY             object
# NAME_PORTFOLIO                  object
# ...

# %% [markdown]
# ## Sample submission

# %%
print(sample_submission.shape)
display(sample_submission.dtypes)
display(sample_submission.isnull().mean()*100)
display(sample_submission.head(3))
# Out:
# (48744, 2)
# SK_ID_CURR      int64
# TARGET        float64
# dtype: object
# SK_ID_CURR    0.0
# TARGET        0.0
# dtype: float64
#    SK_ID_CURR  TARGET
# 0      100001     0.5
# 1      100005     0.5
# 2      100013     0.5
